# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
! pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Requirement already satisfied: citipy in /Users/cerda005/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/cerda005/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#print(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Import Open Weather Map Wrapper
import openweathermapy.core as owm

# Set up list and parameters
weather_json = [] #list of json FILES 
params = {'units' : 'imperial', 'appid' : api_key}
    
for i in range(0,len(cities)):
    try:
        weather_json.append(owm.get_current(cities[i], **params))
    except:
        print(f"{i} Record NOT FOUND , SKIP {cities[i]} ")
    print(f"{i} Record FOUND for {cities[i]} ")
# Out:
# 0 Record FOUND for punta arenas
# 1 Record NOT FOUND , SKIP taolanaro
# 1 Record FOUND for taolanaro
# 2 Record FOUND for mataura
# 3 Record FOUND for hilo
# 4 Record FOUND for cape town
# 5 Record FOUND for jamestown
# 6 Record FOUND for busselton
# 7 Record NOT FOUND , SKIP bengkulu
# 7 Record FOUND for bengkulu
# 8 Record FOUND for kapaa
# 9 Record FOUND for hithadhoo
# 10 Record FOUND for isangel
# 11 Record NOT FOUND , SKIP asau
# 11 Record FOUND for asau
# 12 Record FOUND for kribi
# 13 Record FOUND for new norfolk
# 14 Record FOUND for barhi
# 15 Record FOUND for tabas
# 16 Record FOUND for broome
# 17 Record FOUND for rocha
# 18 Record FOUND for staropesterevo
# 19 Record FOUND for voghera
# 20 Record FOUND for brownwood
# 21 Record FOUND for hobart
# 22 Record FOUND for namie
# 23 Record NOT FOUND , SKIP taburi
# 23 Record FOUND for taburi
# 24 Record NOT FOUND , SKIP attawapiskat
# 24 Record FOUND for attawapiskat
# 25 Record FOUND for laguna
# 26 Record FOUND for chalisgaon
# 27 Record FOUND for bredasdorp
# 28 Record FOUND for omaruru
# 29 Record FOUND for atuona
# 30 Record FOUND for moron
# 31 Record FOUND for vestmannaeyjar
# 32 Record FOUND for siva
# 33 Record FOUND for matagami
# 34 Record NOT FOUND , SKIP illoqqortoormiut
# 34 Record FOUND for illoqqortoormiut
# 35 Record FOUND for albany
# 36 Record FOUND for torbay
# 37 Record FOUND for mahebourg
# 38 Record FOUND for rikitea
# 39 Record FOUND for barrow
# 40 Record FOUND for qaanaaq
# 41 Record FOUND for ushuaia
# 42 Record FOUND for oistins
# 43 Record FOUND for nome
# 44 Record FOUND for kruisfontein
# 45 Record FOUND for vaini
# 46 Record FOUND for kaitangata
# 47 Record FOUND for tuktoyaktuk
# 48 Record FOUND for airai
# 49 Record FOUND for longyearbyen
# 50 Record FOUND for asamankese
# 51 Record FOUND for port hardy
# 52 Record NOT FOUND , SKIP marcona
# 52 Record FOUND for marcona
# 53 Record FOUND for naivasha
# 54 Record FOUND for yarmouth
# 55 Record FOUND for kongolo
# 56 Record FOUND for faanui
# 57 Record NOT FOUND , SKIP belushya guba
# 57 Record FOUND for belushya guba
# 58 Record FOUND for bima
# 59 Record FOUND for kogon
# 60 Record FOUND for cusuna
# 61 Record FOUND for saskylakh
# 62 Record FOUND for dikson
# 63 Record FOUND for horsham
# 64 Record FOUND for ganzhou
# 65 Record NOT FOUND , SKIP saleaula
# 65 Record FOUND for saleaula
# 66 Record FOUND for guilin
# 572 Record FOUND for half moon bay
# 573 Record FOUND for asyut
# 574 Record FOUND for jiuquan
# 575 Record FOUND for zunyi
# 576 Record FOUND for hualmay
# 577 Record FOUND for salinopolis
# 578 Record FOUND for cockburn town
# 579 Record FOUND for dyersburg
# 580 Record FOUND for west lafayette
# 581 Record FOUND for mount gambier
# 582 Record FOUND for sioux lookout
# 583 Record FOUND for candido de abreu
# 584 Record FOUND for touros
# 585 Record NOT FOUND , SKIP nguiu
# 585 Record FOUND for nguiu
# 586 Record FOUND for newport
# 587 Record FOUND for price
# 588 Record FOUND for conselheiro pena
# 589 Record FOUND for nazareno
# 590 Record FOUND for paragominas
# 591 Record FOUND for dorado
# 592 Record FOUND for banda aceh
# 593 Record FOUND for kota kinabalu
# 594 Record FOUND for leh
# 595 Record FOUND for concordia
# 596 Record FOUND for emilio carranza
# 597 Record FOUND for izumo
# 598 Record FOUND for mineiros
# 599 Record FOUND for awbari
# 600 Record FOUND for gat
# 601 Record FOUND for kardla
# 602 Record NOT FOUND , SKIP tsihombe
# 602 Record FOUND for tsihombe
# 603 Record FOUND for gornoye loo
# 604 Record FOUND for caconda
# 605 Record FOUND for namibe
# 606 Record FOUND for riyadh
# 607 Record FOUND for san juan del sur
# 608 Record FOUND for mildura
# 609 Record FOUND for ekibastuz
# 610 Record FOUND for road town
# 611 Record FOUND for lalmohan
# 612 Record FOUND for igurubi
# 613 Record FOUND for neiafu
# 614 Record FOUND for kungurtug
# 615 Record FOUND for cartagena
# 616 Record NOT FOUND , SKIP tammisaari
# 616 Record FOUND for tammisaari
# 617 Record FOUND for naifaru
# 618 Record FOUND for edwardsville
# 619 Record FOUND for grande prairie
# 620 Record FOUND for rio grande
# 621 Record FOUND for aklavik
# 622 Record FOUND for taiyuan
# 623 Record FOUND for biak
# 624 Record FOUND for karratha
# 625 Record FOUND for abu samrah

# %%
# Check how many valid cities
len(weather_json)
weather_json
# Out:
# [{'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 41,
#    'pressure': 1010,
#    'humidity': 93,
#    'temp_min': 41,
#    'temp_max': 41},
#   'visibility': 10000,
#   'wind': {'speed': 12.75, 'deg': 50},
#   'clouds': {'all': 90},
#   'dt': 1562982388,
#   'sys': {'type': 1,
#    'id': 8487,
#    'message': 0.0068,
#    'country': 'CL',
#    'sunrise': 1562935945,
#    'sunset': 1562964339},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 54,
#    'pressure': 999,
#    'humidity': 73,
#    'temp_min': 54,
#    'temp_max': 54},
#   'wind': {'speed': 1.01, 'deg': 39, 'gust': 1.79},
#   'clouds': {'all': 98},
#   'dt': 1562982388,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'message': 0.0065,
#    'country': 'NZ',
#    'sunrise': 1562963016,
#    'sunset': 1562994982},
#   'timezone': 43200,
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': -155.08, 'lat': 19.71},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 80.06,
#    'pressure': 1014,
#    'humidity': 58,
#    'temp_min': 78.01,
#    'temp_max': 82.4},
#   'visibility': 16093,
#   'wind': {'speed': 10.29, 'deg': 90, 'gust': 7.7},
#   'clouds': {'all': 40},
#   'dt': 1562982388,
#   'sys': {'type': 1,
#    'id': 7881,
#    'message': 0.0068,
#    'country': 'US',
#    'sunrise': 1562946521,
#    'sunset': 1562994167},
#   'timezone': -36000,
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 49.77,
#    'pressure': 1021,
#    'humidity': 100,
#    'temp_min': 44.6,
#    'temp_max': 53.01},
#   'visibility': 10000,
#   'wind': {'speed': 1.12},
#   'clouds': {'all': 0},
#   'dt': 1562982157,
#   'sys': {'type': 1,
#    'id': 1899,
#    'message': 0.008,
#    'country': 'ZA',
#    'sunrise': 1562997001,
#    'sunset': 1563033215},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 51.2,
#    'pressure': 1026.85,
#    'humidity': 64,
#    'temp_min': 51.2,
#    'temp_max': 51.2,
#    'sea_level': 1026.85,
#    'grnd_level': 989.5},
#   'wind': {'speed': 14.36, 'deg': 218.444},
#   'rain': {'3h': 0.438},
#   'clouds': {'all': 15},
#   'dt': 1562982389,
#   'sys': {'message': 0.0061,
#    'country': 'AU',
#    'sunrise': 1562968063,
#    'sunset': 1563004462},
#   'timezone': 34200,
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 51.51,
#    'pressure': 1028,
#    'humidity': 68,
#    'temp_min': 48.99,
#    'temp_max': 57},
#   'wind': {'speed': 12.88, 'deg': 75.715},
#   'clouds': {'all': 44},
#   'dt': 1562982389,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'message': 0.0071,
#    'country': 'AU',
#    'sunrise': 1562973702,
#    'sunset': 1563009984},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 83.57,
#    'pressure': 1015,
#    'humidity': 66,
#    'temp_min': 80.01,
#    'temp_max': 87.8},
#   'visibility': 16093,
#   'wind': {'speed': 13.87, 'deg': 30},
#   'clouds': {'all': 75},
#   'dt': 1562982298,
#   'sys': {'type': 1,
#    'id': 7873,
#    'message': 0.0103,
#    'country': 'US',
#    'sunrise': 1562947269,
#    'sunset': 1562995455},
#   'timezone': -36000,
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200},
#  {'coord': {'lon': 73.08, 'lat': -0.6},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.32,
#    'pressure': 1012.03,
#    'humidity': 75,
#    'temp_min': 84.32,
#    'temp_max': 84.32,
#    'sea_level': 1012.03,
#    'grnd_level': 1011.88},
#   'wind': {'speed': 13.62, 'deg': 110.588},
#   'clouds': {'all': 0},
#   'dt': 1562982389,
#   'sys': {'message': 0.0053,
#    'country': 'MV',
#    'sunrise': 1562980232,
#    'sunset': 1563023745},
#   'timezone': 18000,
#   'id': 1282256,
#   'name': 'Hithadhoo',
#   'cod': 200},
#  {'coord': {'lon': 169.27, 'lat': -19.55},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1014,
#    'humidity': 69,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 130},
#   'clouds': {'all': 75},
#   'dt': 1562982390,
#   'sys': {'type': 1,
#    'id': 7317,
#    'message': 0.0054,
#    'country': 'VU',
#    'sunrise': 1562959044,
#    'sunset': 1562998758},
#   'timezone': 39600,
#   'id': 2136825,
#   'name': 'Isangel',
#   'cod': 200},
#  {'coord': {'lon': 9.91, 'lat': 2.94},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 77.48,
#    'pressure': 1014.64,
#    'humidity': 83,
#    'temp_min': 77.48,
#    'temp_max': 77.48,
#    'sea_level': 1014.64,
#    'grnd_level': 1014.23},
#   'wind': {'speed': 8.61, 'deg': 209.802},
#   'rain': {'3h': 2.5},
#   'clouds': {'all': 77},
#   'dt': 1562982390,
#   'sys': {'message': 0.007,
#    'country': 'CM',
#    'sunrise': 1562995052,
#    'sunset': 1563039249},
#   'timezone': 3600,
#   'id': 2229761,
#   'name': 'Kribi',
#   'cod': 200},
#  {'coord': {'lon': 147.06, 'lat': -42.78},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 43.16,
#    'pressure': 1002,
#    'humidity': 87,
#    'temp_min': 42.8,
#    'temp_max': 44.01},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 270},
#   'clouds': {'all': 75},
#   'dt': 1562982390,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0064,
#    'country': 'AU',
#    'sunrise': 1562967566,
#    'sunset': 1563000897},
#   'timezone': 36000,
#   'id': 2155415,
#   'name': 'New Norfolk',
#   'cod': 200},
#  {'coord': {'lon': 85.42, 'lat': 24.31},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1002,
#    'humidity': 83,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 3000,
#   'wind': {'speed': 2.24, 'deg': 220},
#   'clouds': {'all': 75},
#   'dt': 1562982391,
#   'sys': {'type': 1,
#    'id': 9115,
#    'message': 0.0063,
#    'country': 'IN',
#    'sunrise': 1562974675,
#    'sunset': 1563023378},
#   'timezone': 19800,
#   'id': 1268775,
#   'name': 'Barhi',
#   'cod': 200},
#  {'coord': {'lon': 56.92, 'lat': 33.6},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 89.6,
#    'pressure': 1000,
#    'humidity': 17,
#    'temp_min': 89.6,
#    'temp_max': 89.6},
#   'wind': {'speed': 2.24, 'deg': 50},
#   'clouds': {'all': 18},
#   'dt': 1562982391,
#   'sys': {'type': 1,
#    'id': 7487,
#    'message': 0.0067,
#    'country': 'IR',
#    'sunrise': 1562980283,
#    'sunset': 1563031452},
#   'timezone': 16200,
#   'id': 113659,
#   'name': 'Tabas',
#   'cod': 200},
#  {'coord': {'lon': 1.45, 'lat': 52.47},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 59.16,
#    'pressure': 1019,
#    'humidity': 93,
#    'temp_min': 57,
#    'temp_max': 61},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 300},
#   'clouds': {'all': 37},
#   'dt': 1562982391,
#   'sys': {'type': 1,
#    'id': 1467,
#    'message': 0.01,
#    'country': 'GB',
#    'sunrise': 1562989604,
#    'sunset': 1563048758},
#   'timezone': 3600,
#   'id': 2656067,
#   'name': 'Broome',
#   'cod': 200},
#  {'coord': {'lon': -54.34, 'lat': -34.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 52.28,
#    'pressure': 1014.15,
#    'humidity': 95,
#    'temp_min': 52.28,
#    'temp_max': 52.28,
#    'sea_level': 1014.15,
#    'grnd_level': 1001.08},
#   'wind': {'speed': 11.21, 'deg': 228.665},
#   'clouds': {'all': 97},
#   'dt': 1562982146,
#   'sys': {'message': 0.0065,
#    'country': 'UY',
#    'sunrise': 1562928158,
#    'sunset': 1562964171},
#   'timezone': -10800,
#   'id': 3440777,
#   'name': 'Rocha',
#   'cod': 200},
#  {'coord': {'lon': 86.41, 'lat': 54.5},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 69.38,
#    'pressure': 1013.33,
#    'humidity': 64,
#    'temp_min': 69.38,
#    'temp_max': 69.38,
#    'sea_level': 1013.33,
#    'grnd_level': 986.3},
#   'wind': {'speed': 15.01, 'deg': 46.371},
#   'clouds': {'all': 0},
#   'dt': 1562982392,
#   'sys': {'message': 0.0059,
#    'country': 'RU',
#    'sunrise': 1562968502,
#    'sunset': 1563029076},
#   'timezone': 25200,
#   'id': 1490966,
#   'name': 'Staropesterevo',
#   'cod': 200},
#  {'coord': {'lon': 9.01, 'lat': 44.99},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.57,
#    'pressure': 1009,
#    'humidity': 82,
#    'temp_min': 64.99,
#    'temp_max': 73},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 50},
#   'clouds': {'all': 0},
#   'dt': 1562982392,
#   'sys': {'type': 1,
#    'id': 6742,
#    'message': 0.0099,
#    'country': 'IT',
#    'sunrise': 1562989755,
#    'sunset': 1563044978},
#   'timezone': 7200,
#   'id': 3163995,
#   'name': 'Voghera',
#   'cod': 200},
#  {'coord': {'lon': -98.99, 'lat': 31.71},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 82.87,
#    'pressure': 1013,
#    'humidity': 37,
#    'temp_min': 80.01,
#    'temp_max': 86},
#   'visibility': 16093,
#   'wind': {'speed': 5.82, 'deg': 40},
#   'clouds': {'all': 1},
#   'dt': 1562982392,
#   'sys': {'type': 1,
#    'id': 3676,
#    'message': 0.0072,
#    'country': 'US',
#    'sunrise': 1562931556,
#    'sunset': 1562982207},
#   'timezone': -18000,
#   'id': 4676798,
#   'name': 'Brownwood',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 43.16,
#    'pressure': 1002,
#    'humidity': 87,
#    'temp_min': 42.8,
#    'temp_max': 44.01},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 270},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 75},
#   'dt': 1562982392,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0077,
#    'country': 'AU',
#    'sunrise': 1562967520,
#    'sunset': 1563000814},
#   'timezone': 36000,
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': 140.86, 'lat': 37.52},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 78.64,
#    'pressure': 1006,
#    'humidity': 73,
#    'temp_min': 73.4,
#    'temp_max': 89.01},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 340},
#   'clouds': {'all': 75},
#   'dt': 1562982393,
#   'sys': {'type': 1,
#    'id': 8046,
#    'message': 0.0053,
#    'country': 'JP',
#    'sunrise': 1562959514,
#    'sunset': 1563011926},
#   'timezone': 32400,
#   'id': 2111704,
#   'name': 'Namie',
#   'cod': 200},
#  {'coord': {'lon': -88.94, 'lat': 16.17},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 82.4,
#    'pressure': 1011,
#    'humidity': 74,
#    'temp_min': 82.4,
#    'temp_max': 82.4},
#   'visibility': 10000,
#   'wind': {'speed': 2.73, 'deg': 39.577},
#   'clouds': {'all': 40},
#   'dt': 1562982393,
#   'sys': {'type': 1,
#    'id': 7081,
#    'message': 0.0068,
#    'country': 'BZ',
#    'sunrise': 1562931031,
#    'sunset': 1562977907},
#   'timezone': -21600,
#   'id': 3581398,
#   'name': 'Laguna',
#   'cod': 200},
#  {'coord': {'lon': 75, 'lat': 20.46},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.72,
#    'pressure': 1007.76,
#    'humidity': 72,
#    'temp_min': 80.72,
#    'temp_max': 80.72,
#    'sea_level': 1007.76,
#    'grnd_level': 966.55},
#   'wind': {'speed': 14.5, 'deg': 241.826},
#   'clouds': {'all': 100},
#   'dt': 1562982393,
#   'sys': {'message': 0.0062,
#    'country': 'IN',
#    'sunrise': 1562977626,
#    'sunset': 1563025430},
#   'timezone': 19800,
#   'id': 1274868,
#   'name': 'Chalisgaon',
#   'cod': 200},
#  {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 52.79,
#    'pressure': 1022,
#    'humidity': 82,
#    'temp_min': 51.01,
#    'temp_max': 55.4},
#   'wind': {'speed': 1.63, 'deg': 347.07},
#   'clouds': {'all': 1},
#   'dt': 1562982394,
#   'sys': {'type': 1,
#    'id': 1966,
#    'message': 0.0138,
#    'country': 'ZA',
#    'sunrise': 1562996698,
#    'sunset': 1563032741},
#   'timezone': 7200,
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': 15.95, 'lat': -21.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 51.56,
#    'pressure': 1018.38,
#    'humidity': 52,
#    'temp_min': 51.56,
#    'temp_max': 51.56,
#    'sea_level': 1018.38,
#    'grnd_level': 888.44},
#   'wind': {'speed': 3.38, 'deg': 96.479},
#   'clouds': {'all': 0},
#   'dt': 1562982394,
#   'sys': {'message': 0.007,
#    'country': 'NA',
#    'sunrise': 1562996042,
#    'sunset': 1563035359},
#   'timezone': 7200,
#   'id': 3354540,
#   'name': 'Omaruru',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 80.36,
#    'pressure': 1009.24,
#    'humidity': 75,
#    'temp_min': 80.36,
#    'temp_max': 80.36,
#    'sea_level': 1009.24,
#    'grnd_level': 1009.39},
#   'wind': {'speed': 17.18, 'deg': 89.403},
#   'clouds': {'all': 93},
#   'dt': 1562982394,
#   'sys': {'message': 0.0083,
#    'country': 'PF',
#    'sunrise': 1562945632,
#    'sunset': 1562987352},
#   'timezone': -34200,
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': -74.26, 'lat': 18.56},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 80.36,
#    'pressure': 1014.42,
#    'humidity': 80,
#    'temp_min': 80.36,
#    'temp_max': 80.36,
#    'sea_level': 1014.42,
#    'grnd_level': 1007.45},
#   'wind': {'speed': 4.23, 'deg': 41.717},
#   'rain': {'3h': 0.25},
#   'clouds': {'all': 10},
#   'dt': 1562982394,
#   'sys': {'message': 0.0063,
#    'country': 'HT',
#    'sunrise': 1562927247,
#    'sunset': 1562974644},
#   'timezone': -14400,
#   'id': 3720455,
#   'name': 'Moron',
#   'cod': 200},
#  {'coord': {'lon': -20.27, 'lat': 63.44},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 52.64,
#    'pressure': 1016.42,
#    'humidity': 94,
#    'temp_min': 52.64,
#    'temp_max': 52.64,
#    'sea_level': 1016.42,
#    'grnd_level': 1016.91},
#   'wind': {'speed': 7.43, 'deg': 157.348},
#   'clouds': {'all': 96},
#   'dt': 1562982395,
#   'sys': {'message': 0.0074,
#    'country': 'IS',
#    'sunrise': 1562989145,
#    'sunset': 1563059644},
#   'timezone': 0,
#   'id': 3412093,
#   'name': 'Vestmannaeyjar',
#   'cod': 200},
#  {'coord': {'lon': 25.04, 'lat': 35.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 69.49,
#    'pressure': 1011,
#    'humidity': 72,
#    'temp_min': 66.99,
#    'temp_max': 75.99},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1562982395,
#   'sys': {'type': 1,
#    'id': 6616,
#    'message': 0.0074,
#    'country': 'GR',
#    'sunrise': 1562987693,
#    'sunset': 1563039345},
#   'timezone': 10800,
#   'id': 6697802,
#   'name': 'Siva',
#   'cod': 200},
#  {'coord': {'lon': 8.4, 'lat': 9.67},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 66.5,
#    'pressure': 1014.5,
#    'humidity': 99,
#    'temp_min': 66.5,
#    'temp_max': 66.5,
#    'sea_level': 1014.5,
#    'grnd_level': 935},
#   'wind': {'speed': 4.59, 'deg': 155.262},
#   'clouds': {'all': 99},
#   'dt': 1562982395,
#   'sys': {'message': 0.0089,
#    'country': 'NG',
#    'sunrise': 1562994753,
#    'sunset': 1563040273},
#   'timezone': 3600,
#   'id': 2335713,
#   'name': 'Matagami',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 69.75,
#    'pressure': 1009,
#    'humidity': 69,
#    'temp_min': 64.99,
#    'temp_max': 73.99},
#   'visibility': 16093,
#   'wind': {'speed': 8.05, 'deg': 280},
#   'clouds': {'all': 40},
#   'dt': 1562982367,
#   'sys': {'type': 1,
#    'id': 3273,
#    'message': 0.009,
#    'country': 'US',
#    'sunrise': 1562923669,
#    'sunset': 1562977978},
#   'timezone': -14400,
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': -52.73, 'lat': 47.66},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 48.92,
#    'pressure': 1019,
#    'humidity': 87,
#    'temp_min': 46.99,
#    'temp_max': 51.01},
#   'visibility': 24140,
#   'wind': {'speed': 2.24, 'deg': 230},
#   'clouds': {'all': 20},
#   'dt': 1562982396,
#   'sys': {'type': 1,
#    'id': 998,
#    'message': 0.0064,
#    'country': 'CA',
#    'sunrise': 1562917507,
#    'sunset': 1562974049},
#   'timezone': -9000,
#   'id': 6167817,
#   'name': 'Torbay',
#   'cod': 200},
#  {'coord': {'lon': 57.7, 'lat': -20.41},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 65.52,
#    'pressure': 1020,
#    'humidity': 72,
#    'temp_min': 64.99,
#    'temp_max': 66.2},
#   'visibility': 10000,
#   'wind': {'speed': 4.5, 'deg': 115.07},
#   'clouds': {'all': 20},
#   'dt': 1562982396,
#   'sys': {'type': 1,
#    'id': 2061,
#    'message': 0.0075,
#    'country': 'MU',
#    'sunrise': 1562985912,
#    'sunset': 1563025448},
#   'timezone': 14400,
#   'id': 934322,
#   'name': 'Mahebourg',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 74.42,
#    'pressure': 1014.23,
#    'humidity': 78,
#    'temp_min': 74.42,
#    'temp_max': 74.42,
#    'sea_level': 1014.23,
#    'grnd_level': 1014.04},
#   'wind': {'speed': 14.14, 'deg': 356.436},
#   'clouds': {'all': 62},
#   'dt': 1562982397,
#   'sys': {'message': 0.0066,
#    'country': 'PF',
#    'sunrise': 1562946059,
#    'sunset': 1562984976},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': -60.23, 'lat': -38.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 42.2,
#    'pressure': 1017.68,
#    'humidity': 77,
#    'temp_min': 42.2,
#    'temp_max': 42.2,
#    'sea_level': 1017.68,
#    'grnd_level': 1006.36},
#   'wind': {'speed': 4.92, 'deg': 250.355},
#   'clouds': {'all': 0},
#   'dt': 1562982397,
#   'sys': {'message': 0.0062,
#    'country': 'AR',
#    'sunrise': 1562930154,
#    'sunset': 1562965002},
#   'timezone': -10800,
#   'id': 3833859,
#   'name': 'Barrow',
#   'cod': 200},
#  {'coord': {'lon': -69.36, 'lat': 77.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 43.64,
#    'pressure': 1012.76,
#    'humidity': 64,
#    'temp_min': 43.64,
#    'temp_max': 43.64,
#    'sea_level': 1012.76,
#    'grnd_level': 974.6},
#   'wind': {'speed': 6.67, 'deg': 80.718},
#   'clouds': {'all': 100},
#   'dt': 1562982397,
#   'sys': {'message': 0.0077, 'country': 'GL', 'sunrise': 0, 'sunset': 0},
#   'timezone': -10800,
#   'id': 3831208,
#   'name': 'Qaanaaq',
#   'cod': 200},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 39.2,
#    'pressure': 1012,
#    'humidity': 80,
#    'temp_min': 39.2,
#    'temp_max': 39.2},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 320},
#   'clouds': {'all': 40},
#   'dt': 1562982397,
#   'sys': {'type': 1,
#    'id': 8303,
#    'message': 0.0062,
#    'country': 'AR',
#    'sunrise': 1562935849,
#    'sunset': 1562963186},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': -59.53, 'lat': 13.07},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1014,
#    'humidity': 83,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 14.99, 'deg': 100},
#   'clouds': {'all': 75},
#   'dt': 1562982398,
#   'sys': {'type': 1,
#    'id': 8772,
#    'message': 0.0076,
#    'country': 'BB',
#    'sunrise': 1562924298,
#    'sunset': 1562970523},
#   'timezone': -14400,
#   'id': 3373652,
#   'name': 'Oistins',
#   'cod': 200},
#  {'coord': {'lon': -94.42, 'lat': 30.04},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 85.08,
#    'pressure': 1005,
#    'humidity': 74,
#    'temp_min': 81,
#    'temp_max': 89.01},
#   'visibility': 16093,
#   'wind': {'speed': 8.05, 'deg': 350},
#   'clouds': {'all': 20},
#   'dt': 1562982398,
#   'sys': {'type': 1,
#    'id': 3495,
#    'message': 0.0067,
#    'country': 'US',
#    'sunrise': 1562930691,
#    'sunset': 1562980879},
#   'timezone': -18000,
#   'id': 4732862,
#   'name': 'Nome',
#   'cod': 200},
#  {'coord': {'lon': 24.73, 'lat': -34},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 50.12,
#    'pressure': 1021.43,
#    'humidity': 93,
#    'temp_min': 50.12,
#    'temp_max': 50.12,
#    'sea_level': 1021.43,
#    'grnd_level': 989.59},
#   'wind': {'speed': 4.47, 'deg': 20.442},
#   'clouds': {'all': 9},
#   'dt': 1562982398,
#   'sys': {'message': 0.007,
#    'country': 'ZA',
#    'sunrise': 1562995497,
#    'sunset': 1563031690},
#   'timezone': 7200,
#   'id': 986717,
#   'name': 'Kruisfontein',
#   'cod': 200},
#  {'coord': {'lon': 74.49, 'lat': 15.34},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 71.6,
#    'pressure': 1013,
#    'humidity': 100,
#    'temp_min': 71.6,
#    'temp_max': 71.6},
#   'visibility': 4000,
#   'wind': {'speed': 5.82, 'deg': 270},
#   'clouds': {'all': 90},
#   'dt': 1562982398,
#   'sys': {'type': 1,
#    'id': 9229,
#    'message': 0.0089,
#    'country': 'IN',
#    'sunrise': 1562978307,
#    'sunset': 1563024994},
#   'timezone': 19800,
#   'id': 1273574,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': 169.85, 'lat': -46.28},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 51.01,
#    'pressure': 996,
#    'humidity': 62,
#    'temp_min': 51.01,
#    'temp_max': 51.01},
#   'wind': {'speed': 1.99, 'deg': 180, 'gust': 0.89},
#   'clouds': {'all': 100},
#   'dt': 1562982399,
#   'sys': {'type': 3,
#    'id': 2000217,
#    'message': 0.008,
#    'country': 'NZ',
#    'sunrise': 1562962798,
#    'sunset': 1562994725},
#   'timezone': 43200,
#   'id': 2208248,
#   'name': 'Kaitangata',
#   'cod': 200},
#  {'coord': {'lon': -133.03, 'lat': 69.44},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 46.4,
#    'pressure': 1012,
#    'humidity': 75,
#    'temp_min': 46.4,
#    'temp_max': 46.4},
#   'visibility': 24140,
#   'wind': {'speed': 6.93, 'deg': 350},
#   'clouds': {'all': 75},
#   'dt': 1562982399,
#   'sys': {'type': 1,
#    'id': 942,
#    'message': 0.0065,
#    'country': 'CA',
#    'sunrise': 0,
#    'sunset': 0},
#   'timezone': -21600,
#   'id': 6170031,
#   'name': 'Tuktoyaktuk',
#   'cod': 200},
#  {'coord': {'lon': 125.41, 'lat': -8.93},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 81.26,
#    'pressure': 1014.69,
#    'humidity': 47,
#    'temp_min': 81.26,
#    'temp_max': 81.26,
#    'sea_level': 1014.69,
#    'grnd_level': 979.03},
#   'wind': {'speed': 3.13, 'deg': 318.104},
#   'clouds': {'all': 80},
#   'dt': 1562982399,
#   'sys': {'message': 0.0087,
#    'country': 'TL',
#    'sunrise': 1562968480,
#    'sunset': 1563010376},
#   'timezone': 32400,
#   'id': 1651810,
#   'name': 'Airai',
#   'cod': 200},
#  {'coord': {'lon': 15.63, 'lat': 78.22},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 37.88,
#    'pressure': 1015.38,
#    'humidity': 87,
#    'temp_min': 37.88,
#    'temp_max': 37.88,
#    'sea_level': 1015.38,
#    'grnd_level': 996.25},
#   'wind': {'speed': 10.11, 'deg': 212.455},
#   'clouds': {'all': 100},
#   'dt': 1562982103,
#   'sys': {'message': 0.0059, 'country': 'NO', 'sunrise': 0, 'sunset': 0},
#   'timezone': 7200,
#   'id': 2729907,
#   'name': 'Longyearbyen',
#   'cod': 200},
#  {'coord': {'lon': -0.66, 'lat': 5.86},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1014,
#    'humidity': 94,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 220},
#   'clouds': {'all': 75},
#   'dt': 1562982400,
#   'sys': {'type': 1,
#    'id': 1126,
#    'message': 0.0061,
#    'country': 'GH',
#    'sunrise': 1562997305,
#    'sunset': 1563042070},
#   'timezone': 0,
#   'id': 2304220,
#   'name': 'Asamankese',
#   'cod': 200},
#  {'coord': {'lon': -127.42, 'lat': 50.7},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.6,
#    'pressure': 1017,
#    'humidity': 82,
#    'temp_min': 62.6,
#    'temp_max': 62.6},
#   'visibility': 32186,
#   'wind': {'speed': 5.82, 'deg': 350},
#   'clouds': {'all': 90},
#   'dt': 1562982400,
#   'sys': {'type': 1,
#    'id': 1011,
#    'message': 0.0074,
#    'country': 'CA',
#    'sunrise': 1562934629,
#    'sunset': 1562992781},
#   'timezone': -25200,
#   'id': 6111862,
#   'name': 'Port Hardy',
#   'cod': 200},
#  {'coord': {'lon': 36.43, 'lat': -0.72},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 54,
#    'pressure': 1014,
#    'humidity': 87,
#    'temp_min': 54,
#    'temp_max': 54},
#   'wind': {'speed': 5.01, 'deg': 71, 'gust': 4.92},
#   'clouds': {'all': 79},
#   'dt': 1562982400,
#   'sys': {'type': 3,
#    'id': 2006176,
#    'message': 0.0071,
#    'country': 'KE',
#    'sunrise': 1562989040,
#    'sunset': 1563032531},
#   'timezone': 10800,
#   'id': 184707,
#   'name': 'Naivasha',
#   'cod': 200},
#  {'coord': {'lon': -66.12, 'lat': 43.84},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 64.85,
#    'pressure': 1007,
#    'humidity': 93,
#    'temp_min': 64.4,
#    'temp_max': 64.99},
#   'visibility': 19312,
#   'wind': {'speed': 9.17, 'deg': 120},
#   'clouds': {'all': 40},
#   'dt': 1562982401,
#   'sys': {'type': 1,
#    'id': 893,
#    'message': 0.0061,
#    'country': 'CA',
#    'sunrise': 1562921593,
#    'sunset': 1562976391},
#   'timezone': -10800,
#   'id': 6185217,
#   'name': 'Yarmouth',
#   'cod': 200},
#  {'coord': {'lon': 27, 'lat': -5.39},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 68.3,
#    'pressure': 1014.37,
#    'humidity': 85,
#    'temp_min': 68.3,
#    'temp_max': 68.3,
#    'sea_level': 1014.37,
#    'grnd_level': 939.1},
#   'wind': {'speed': 3.85, 'deg': 345.058},
#   'rain': {'3h': 0.188},
#   'clouds': {'all': 32},
#   'dt': 1562982401,
#   'sys': {'message': 0.0068,
#    'country': 'CD',
#    'sunrise': 1562991754,
#    'sunset': 1563034343},
#   'timezone': 7200,
#   'id': 212360,
#   'name': 'Kongolo',
#   'cod': 200},
#  {'coord': {'lon': -151.75, 'lat': -16.48},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 78.02,
#    'pressure': 1010.09,
#    'humidity': 68,
#    'temp_min': 78.02,
#    'temp_max': 78.02,
#    'sea_level': 1010.09,
#    'grnd_level': 1010.14},
#   'wind': {'speed': 4.16, 'deg': 196.374},
#   'clouds': {'all': 0},
#   'dt': 1562982401,
#   'sys': {'message': 0.0059,
#    'country': 'PF',
#    'sunrise': 1562949363,
#    'sunset': 1562989727},
#   'timezone': -36000,
#   'id': 4034551,
#   'name': 'Faanui',
#   'cod': 200},
#  {'coord': {'lon': 118.73, 'lat': -8.45},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 80.18,
#    'pressure': 1014.83,
#    'humidity': 49,
#    'temp_min': 80.18,
#    'temp_max': 80.18,
#    'sea_level': 1014.83,
#    'grnd_level': 977.5},
#   'wind': {'speed': 8.16, 'deg': 133.7},
#   'clouds': {'all': 27},
#   'dt': 1562982402,
#   'sys': {'message': 0.0064,
#    'country': 'ID',
#    'sunrise': 1562970036,
#    'sunset': 1563012027},
#   'timezone': 28800,
#   'id': 1648759,
#   'name': 'Bima',
#   'cod': 200},
#  {'coord': {'lon': 64.54, 'lat': 39.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.48,
#    'pressure': 999,
#    'humidity': 26,
#    'temp_min': 77,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 340},
#   'clouds': {'all': 0},
#   'dt': 1562982402,
#   'sys': {'type': 1,
#    'id': 9009,
#    'message': 0.0069,
#    'country': 'UZ',
#    'sunrise': 1562977458,
#    'sunset': 1563030618},
#   'timezone': 18000,
#   'id': 1217180,
#   'name': 'Kogon',
#   'cod': 200},
#  {'coord': {'lon': -85.23, 'lat': 15.85},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 82.34,
#    'pressure': 1012.97,
#    'humidity': 78,
#    'temp_min': 82.34,
#    'temp_max': 82.34,
#    'sea_level': 1012.97,
#    'grnd_level': 1012.36},
#   'wind': {'speed': 18.52, 'deg': 96.518},
#   'clouds': {'all': 0},
#   'dt': 1562982402,
#   'sys': {'message': 0.006,
#    'country': 'HN',
#    'sunrise': 1562930175,
#    'sunset': 1562976983},
#   'timezone': -21600,
#   'id': 3612949,
#   'name': 'Cusuna',
#   'cod': 200},
#  {'coord': {'lon': 114.09, 'lat': 71.97},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 55.88,
#    'pressure': 1007.84,
#    'humidity': 57,
#    'temp_min': 55.88,
#    'temp_max': 55.88,
#    'sea_level': 1007.84,
#    'grnd_level': 998.11},
#   'wind': {'speed': 7.83, 'deg': 147.031},
#   'rain': {'3h': 0.125},
#   'clouds': {'all': 100},
#   'dt': 1562982402,
#   'sys': {'message': 0.0058, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 32400,
#   'id': 2017155,
#   'name': 'Saskylakh',
#   'cod': 200},
#  {'coord': {'lon': 80.55, 'lat': 73.51},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 32.48,
#    'pressure': 1014.44,
#    'humidity': 96,
#    'temp_min': 32.48,
#    'temp_max': 32.48,
#    'sea_level': 1014.44,
#    'grnd_level': 1014.03},
#   'wind': {'speed': 13.8, 'deg': 23.051},
#   'clouds': {'all': 61},
#   'dt': 1562982403,
#   'sys': {'message': 0.0072, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 25200,
#   'id': 1507390,
#   'name': 'Dikson',
#   'cod': 200},
#  {'coord': {'lon': 142.2, 'lat': -36.71},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 50.48,
#    'pressure': 1020.24,
#    'humidity': 61,
#    'temp_min': 50.48,
#    'temp_max': 50.48,
#    'sea_level': 1020.24,
#    'grnd_level': 997.58},
#   'wind': {'speed': 18.61, 'deg': 230.181},
#   'rain': {'3h': 0.188},
#   'clouds': {'all': 0},
#   'dt': 1562982403,
#   'sys': {'message': 0.0058,
#    'country': 'AU',
#    'sunrise': 1562967710,
#    'sunset': 1563003087},
#   'timezone': 36000,
#   'id': 2163055,
#   'name': 'Horsham',
#   'cod': 200},
#  {'coord': {'lon': 114.93, 'lat': 25.86},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 81.8,
#    'pressure': 1003.98,
#    'humidity': 76,
#    'temp_min': 81.8,
#    'temp_max': 81.8,
#    'sea_level': 1003.98,
#    'grnd_level': 961.29},
#   'wind': {'speed': 8.03, 'deg': 218.473},
#   'rain': {'3h': 0.188},
#   'clouds': {'all': 100},
#   'dt': 1562982403,
#   'sys': {'message': 0.0062,
#    'country': 'CN',
#    'sunrise': 1562967401,
#    'sunset': 1563016486},
#   'timezone': 28800,
#   'id': 1810638,
#   'name': 'Ganzhou',
#   'cod': 200},
#  {'coord': {'lon': 110.29, 'lat': 25.28},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'pressure': 1004,
#    'humidity': 100,
#    'temp_min': 75.2,
#    'temp_max': 75.2},
#   'visibility': 7000,
#   'wind': {'speed': 2.24},
#   'clouds': {'all': 75},
#   'dt': 1562982403,
#   'sys': {'type': 1,
#    'id': 9626,
#    'message': 0.006,
#    'country': 'CN',
#    'sunrise': 1562968587,
#    'sunset': 1563017528},
#   'timezone': 28800,
#   'id': 1809498,
#   'name': 'Guilin',
#   'cod': 200},
#  {'coord': {'lon': 38.73, 'lat': 8.96},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 55.52,
#    'pressure': 1018.3,
#    'humidity': 94,
#    'temp_min': 55.52,
#    'temp_max': 55.52,
#    'sea_level': 1018.3,
#    'grnd_level': 772.83},
#   'wind': {'speed': 1.21, 'deg': 280.626},
#   'rain': {'3h': 1},
#   'clouds': {'all': 100},
#   'dt': 1562982404,
#   'sys': {'message': 0.0062,
#    'country': 'ET',
#    'sunrise': 1562987544,
#    'sunset': 1563032923},
#   'timezone': 10800,
#   'id': 344979,
#   'name': 'Lebu',
#   'cod': 200},
#  {'coord': {'lon': -124.16, 'lat': 40.6},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.49,
#    'pressure': 1017,
#    'humidity': 87,
#    'temp_min': 60.8,
#    'temp_max': 64.4},
#   'visibility': 16093,
#   'wind': {'speed': 13.87, 'deg': 280},
#   'clouds': {'all': 90},
#   'dt': 1562982404,
#   'sys': {'type': 1,
#    'id': 4127,
#    'message': 0.0078,
#    'country': 'US',
#    'sunrise': 1562936167,
#    'sunset': 1562989678},
#   'timezone': -25200,
#   'id': 5563839,
#   'name': 'Fortuna',
#   'cod': 200},
#  {'coord': {'lon': 134.5, 'lat': 33.93},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 76.05,
#    'pressure': 1005,
#    'humidity': 88,
#    'temp_min': 73.4,
#    'temp_max': 79},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1562982404,
#   'sys': {'type': 1,
#    'id': 8027,
#    'message': 0.0063,
#    'country': 'JP',
#    'sunrise': 1562961607,
#    'sunset': 1563012886},
#   'timezone': 32400,
#   'id': 1865309,
#   'name': 'Katsuura',
#   'cod': 200},
#  {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 51.01,
#    'pressure': 1018,
#    'humidity': 94,
#    'temp_min': 51.01,
#    'temp_max': 51.01},
#   'wind': {'speed': 10.94, 'deg': 76.268},
#   'clouds': {'all': 0},
#   'dt': 1562982404,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'message': 0.0067,
#    'country': 'ZA',
#    'sunrise': 1562996874,
#    'sunset': 1563032949},
#   'timezone': 7200,
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': -74.86, 'lat': 49.78},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 59,
#    'pressure': 1007,
#    'humidity': 93,
#    'temp_min': 59,
#    'temp_max': 59},
#   'visibility': 14484,
#   'wind': {'speed': 3.36, 'deg': 260},
#   'clouds': {'all': 75},
#   'dt': 1562982227,
#   'sys': {'type': 1,
#    'id': 859,
#    'message': 0.0058,
#    'country': 'CA',
#    'sunrise': 1562922266,
#    'sunset': 1562979913},
#   'timezone': -14400,
#   'id': 5919850,
#   'name': 'Chapais',
#   'cod': 200},
#  {'coord': {'lon': 57.76, 'lat': -20.21},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 65.59,
#    'pressure': 1020,
#    'humidity': 72,
#    'temp_min': 64.99,
#    'temp_max': 66.2},
#   'visibility': 10000,
#   'wind': {'speed': 4.5, 'deg': 115.07},
#   'clouds': {'all': 20},
#   'dt': 1562982405,
#   'sys': {'type': 1,
#    'id': 2061,
#    'message': 0.0081,
#    'country': 'MU',
#    'sunrise': 1562985876,
#    'sunset': 1563025455},
#   'timezone': 14400,
#   'id': 1106643,
#   'name': 'Quatre Cocos',
#   'cod': 200},
#  {'coord': {'lon': 94.9, 'lat': 27.48},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'pressure': 1003,
#    'humidity': 100,
#    'temp_min': 75.2,
#    'temp_max': 75.2},
#   'visibility': 2000,
#   'wind': {'speed': 4.7, 'deg': 40},
#   'clouds': {'all': 90},
#   'dt': 1562982405,
#   'sys': {'type': 1,
#    'id': 9126,
#    'message': 0.0069,
#    'country': 'IN',
#    'sunrise': 1562972006,
#    'sunset': 1563021497},
#   'timezone': 19800,
#   'id': 1272648,
#   'name': 'Dibrugarh',
#   'cod': 200},
#  {'coord': {'lon': 118.58, 'lat': -20.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'pressure': 1023,
#    'humidity': 14,
#    'temp_min': 75.2,
#    'temp_max': 75.2},
#   'visibility': 10000,
#   'wind': {'speed': 21.92, 'deg': 110, 'gust': 14.9},
#   'clouds': {'all': 0},
#   'dt': 1562982406,
#   'sys': {'type': 1,
#    'id': 9585,
#    'message': 0.0073,
#    'country': 'AU',
#    'sunrise': 1562971291,
#    'sunset': 1563010844},
#   'timezone': 28800,
#   'id': 2063042,
#   'name': 'Port Hedland',
#   'cod': 200},
#  {'coord': {'lon': 115.17, 'lat': 52.7},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 81.8,
#    'pressure': 1005.55,
#    'humidity': 30,
#    'temp_min': 81.8,
#    'temp_max': 81.8,
#    'sea_level': 1005.55,
#    'grnd_level': 893.08},
#   'wind': {'speed': 6.38, 'deg': 303.378},
#   'clouds': {'all': 79},
#   'dt': 1562982406,
#   'sys': {'message': 0.0061,
#    'country': 'RU',
#    'sunrise': 1562962215,
#    'sunset': 1563021557},
#   'timezone': 32400,
#   'id': 2013459,
#   'name': 'Verkh-Usugli',
#   'cod': 200},
#  {'coord': {'lon': 130.41, 'lat': 67.8},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 65.06,
#    'pressure': 1006.84,
#    'humidity': 68,
#    'temp_min': 65.06,
#    'temp_max': 65.06,
#    'sea_level': 1006.84,
#    'grnd_level': 905.95},
#   'wind': {'speed': 6.13, 'deg': 97.755},
#   'rain': {'3h': 0.438},
#   'clouds': {'all': 99},
#   'dt': 1562982406,
#   'sys': {'message': 0.007, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 32400,
#   'id': 2027042,
#   'name': 'Batagay-Alyta',
#   'cod': 200},
#  {'coord': {'lon': 149.07, 'lat': -23.58},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 71.54,
#    'pressure': 1019.3,
#    'humidity': 35,
#    'temp_min': 71.54,
#    'temp_max': 71.54,
#    'sea_level': 1019.3,
#    'grnd_level': 998.91},
#   'wind': {'speed': 3.11, 'deg': 86.287},
#   'clouds': {'all': 37},
#   'dt': 1562982406,
#   'sys': {'message': 0.0087,
#    'country': 'AU',
#    'sunrise': 1562964340,
#    'sunset': 1563003158},
#   'timezone': 36000,
#   'id': 2175403,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': 128.74, 'lat': -15.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1020,
#    'humidity': 15,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 19.46, 'deg': 110},
#   'clouds': {'all': 0},
#   'dt': 1562982407,
#   'sys': {'type': 1,
#    'id': 9587,
#    'message': 0.0059,
#    'country': 'AU',
#    'sunrise': 1562968371,
#    'sunset': 1563008887},
#   'timezone': 28800,
#   'id': 2068110,
#   'name': 'Kununurra',
#   'cod': 200},
#  {'coord': {'lon': -84.68, 'lat': 34.07},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 78.75,
#    'pressure': 1016,
#    'humidity': 74,
#    'temp_min': 72,
#    'temp_max': 86},
#   'visibility': 16093,
#   'wind': {'speed': 4.7, 'deg': 290},
#   'rain': {'1h': 3.21},
#   'clouds': {'all': 75},
#   'dt': 1562982407,
#   'sys': {'type': 1,
#    'id': 5747,
#    'message': 0.0094,
#    'country': 'US',
#    'sunrise': 1562927775,
#    'sunset': 1562979118},
#   'timezone': -14400,
#   'id': 4179074,
#   'name': 'Acworth',
#   'cod': 200},
#  {'coord': {'lon': 146.03, 'lat': -17.52},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 69.01,
#    'pressure': 1015,
#    'humidity': 63,
#    'temp_min': 69.01,
#    'temp_max': 69.01},
#   'wind': {'speed': 7, 'deg': 145, 'gust': 6.71},
#   'rain': {'3h': 0.25},
#   'clouds': {'all': 58},
#   'dt': 1562982407,
#   'sys': {'type': 3,
#    'id': 20843,
#    'message': 0.007,
#    'country': 'AU',
#    'sunrise': 1562964404,
#    'sunset': 1563004554},
#   'timezone': 36000,
#   'id': 2162683,
#   'name': 'Innisfail',
#   'cod': 200},
#  {'coord': {'lon': -64.33, 'lat': -23.13},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 61.28,
#    'pressure': 1015.37,
#    'humidity': 91,
#    'temp_min': 61.28,
#    'temp_max': 61.28,
#    'sea_level': 1015.37,
#    'grnd_level': 948.04},
#   'wind': {'speed': 0.56, 'deg': 171.581},
#   'rain': {'3h': 0.312},
#   'clouds': {'all': 100},
#   'dt': 1562982408,
#   'sys': {'message': 0.0052,
#    'country': 'AR',
#    'sunrise': 1562929109,
#    'sunset': 1562968016},
#   'timezone': -10800,
#   'id': 3836620,
#   'name': 'San Ramon de la Nueva Oran',
#   'cod': 200},
#  {'coord': {'lon': 166.1, 'lat': 60.47},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 59.66,
#    'pressure': 1011.08,
#    'humidity': 66,
#    'temp_min': 59.66,
#    'temp_max': 59.66,
#    'sea_level': 1011.08,
#    'grnd_level': 999.13},
#   'wind': {'speed': 8.79, 'deg': 176.977},
#   'clouds': {'all': 26},
#   'dt': 1562982408,
#   'sys': {'message': 0.0074,
#    'country': 'RU',
#    'sunrise': 1562946554,
#    'sunset': 1563012770},
#   'timezone': 43200,
#   'id': 2120591,
#   'name': 'Tilichiki',
#   'cod': 200},
#  {'coord': {'lon': 132.26, 'lat': -14.47},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 78.8,
#    'pressure': 1019,
#    'humidity': 27,
#    'temp_min': 78.8,
#    'temp_max': 78.8},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 120},
#   'clouds': {'all': 34},
#   'dt': 1562982408,
#   'sys': {'type': 1,
#    'id': 9589,
#    'message': 0.0109,
#    'country': 'AU',
#    'sunrise': 1562967392,
#    'sunset': 1563008176},
#   'timezone': 34200,
#   'id': 2068655,
#   'name': 'Katherine',
#   'cod': 200},
#  {'coord': {'lon': -73.76, 'lat': -42.48},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 46.4,
#    'pressure': 1009,
#    'humidity': 93,
#    'temp_min': 46.4,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 14.99, 'deg': 360},
#   'clouds': {'all': 90},
#   'dt': 1562982408,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.0062,
#    'country': 'CL',
#    'sunrise': 1562934119,
#    'sunset': 1562967532},
#   'timezone': -14400,
#   'id': 3896218,
#   'name': 'Castro',
#   'cod': 200},
#  {'coord': {'lon': -42.08, 'lat': -9.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.18,
#    'pressure': 1016.62,
#    'humidity': 69,
#    'temp_min': 71.18,
#    'temp_max': 71.18,
#    'sea_level': 1016.62,
#    'grnd_level': 962.22},
#   'wind': {'speed': 6.08, 'deg': 99.507},
#   'clouds': {'all': 0},
#   'dt': 1562982156,
#   'sys': {'message': 0.0056,
#    'country': 'BR',
#    'sunrise': 1562922346,
#    'sunset': 1562964098},
#   'timezone': -10800,
#   'id': 3408064,
#   'name': 'Remanso',
#   'cod': 200},
#  {'coord': {'lon': -41.14, 'lat': -14.61},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 60.8,
#    'pressure': 1023,
#    'humidity': 82,
#    'temp_min': 60.8,
#    'temp_max': 60.8},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 130},
#   'clouds': {'all': 0},
#   'dt': 1562982409,
#   'sys': {'type': 1,
#    'id': 8416,
#    'message': 0.0069,
#    'country': 'BR',
#    'sunrise': 1562922624,
#    'sunset': 1562963369},
#   'timezone': -10800,
#   'id': 3472298,
#   'name': 'Anage',
#   'cod': 200},
#  {'coord': {'lon': 6.91, 'lat': 62.91},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 50.54,
#    'pressure': 1015,
#    'humidity': 81,
#    'temp_min': 45,
#    'temp_max': 55.4},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 30},
#   'clouds': {'all': 100},
#   'dt': 1562982409,
#   'sys': {'type': 1,
#    'id': 1602,
#    'message': 0.0081,
#    'country': 'NO',
#    'sunrise': 1562983073,
#    'sunset': 1563052668},
#   'timezone': 7200,
#   'id': 7626370,
#   'name': 'Bud',
#   'cod': 200},
#  {'coord': {'lon': -55.87, 'lat': -1.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 77.48,
#    'pressure': 1012.96,
#    'humidity': 83,
#    'temp_min': 77.48,
#    'temp_max': 77.48,
#    'sea_level': 1012.96,
#    'grnd_level': 1012.06},
#   'wind': {'speed': 6.4, 'deg': 113.275},
#   'clouds': {'all': 0},
#   'dt': 1562982307,
#   'sys': {'message': 0.0065,
#    'country': 'BR',
#    'sunrise': 1562924888,
#    'sunset': 1562968175},
#   'timezone': -10800,
#   'id': 3393471,
#   'name': 'Oriximina',
#   'cod': 200},
#  {'coord': {'lon': 111.97, 'lat': 43.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 80,
#    'pressure': 1004.53,
#    'humidity': 32,
#    'temp_min': 80,
#    'temp_max': 80,
#    'sea_level': 1004.53,
#    'grnd_level': 891.35},
#   'wind': {'speed': 11.25, 'deg': 112.3},
#   'clouds': {'all': 0},
#   'dt': 1562982410,
#   'sys': {'message': 0.0056,
#    'country': 'CN',
#    'sunrise': 1562965316,
#    'sunset': 1563019993},
#   'timezone': 28800,
#   'id': 2037485,
#   'name': 'Erenhot',
#   'cod': 200},
#  {'coord': {'lon': 158.65, 'lat': 53.05},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
# ...
#   'id': 3514843,
#   'name': 'Emilio Carranza',
#   'cod': 200},
#  {'coord': {'lon': 132.75, 'lat': 35.37},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'pressure': 1004,
#    'humidity': 83,
#    'temp_min': 73.4,
#    'temp_max': 73.4},
#   'visibility': 10000,
#   'wind': {'speed': 1.12},
#   'clouds': {'all': 75},
#   'dt': 1562982322,
#   'sys': {'type': 1,
#    'id': 8026,
#    'message': 0.0071,
#    'country': 'JP',
#    'sunrise': 1562961807,
#    'sunset': 1563013526},
#   'timezone': 32400,
#   'id': 1861084,
#   'name': 'Izumo',
#   'cod': 200},
#  {'coord': {'lon': -52.55, 'lat': -17.57},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 63.62,
#    'pressure': 1016.46,
#    'humidity': 53,
#    'temp_min': 63.62,
#    'temp_max': 63.62,
#    'sea_level': 1016.46,
#    'grnd_level': 930.67},
#   'wind': {'speed': 1.39, 'deg': 114.634},
#   'clouds': {'all': 0},
#   'dt': 1562982555,
#   'sys': {'message': 0.0063,
#    'country': 'BR',
#    'sunrise': 1562925671,
#    'sunset': 1562965799},
#   'timezone': -10800,
#   'id': 3457147,
#   'name': 'Mineiros',
#   'cod': 200},
#  {'coord': {'lon': 12.77, 'lat': 26.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 85.58,
#    'pressure': 1011.62,
#    'humidity': 12,
#    'temp_min': 85.58,
#    'temp_max': 85.58,
#    'sea_level': 1011.62,
#    'grnd_level': 946.67},
#   'wind': {'speed': 5.28, 'deg': 229.525},
#   'clouds': {'all': 0},
#   'dt': 1562982555,
#   'sys': {'message': 0.0056,
#    'country': 'LY',
#    'sunrise': 1562991836,
#    'sunset': 1563041092},
#   'timezone': 7200,
#   'id': 2219235,
#   'name': 'Awbari',
#   'cod': 200},
#  {'coord': {'lon': -16.54, 'lat': 14.69},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1013,
#    'humidity': 78,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 8000,
#   'wind': {'speed': 6.93, 'deg': 300},
#   'clouds': {'all': 57},
#   'dt': 1562982555,
#   'sys': {'type': 1,
#    'id': 2410,
#    'message': 0.0074,
#    'country': 'SN',
#    'sunrise': 1563000227,
#    'sunset': 1563046772},
#   'timezone': 0,
#   'id': 2249901,
#   'name': 'Gat',
#   'cod': 200},
#  {'coord': {'lon': 26.57, 'lat': 58.44},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 48.07,
#    'pressure': 1009,
#    'humidity': 93,
#    'temp_min': 46,
#    'temp_max': 50},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 260},
#   'clouds': {'all': 85},
#   'dt': 1562982556,
#   'sys': {'type': 1,
#    'id': 1335,
#    'message': 0.01,
#    'country': 'EE',
#    'sunrise': 1562981202,
#    'sunset': 1563045102},
#   'timezone': 10800,
#   'id': 588335,
#   'name': 'Kardla',
#   'cod': 200},
#  {'coord': {'lon': 39.61, 'lat': 43.72},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 66.07,
#    'pressure': 1008,
#    'humidity': 82,
#    'temp_min': 66,
#    'temp_max': 66.2},
#   'visibility': 10000,
#   'wind': {'speed': 4.47, 'deg': 80},
#   'clouds': {'all': 90},
#   'dt': 1562982556,
#   'sys': {'type': 1,
#    'id': 8972,
#    'message': 0.0064,
#    'country': 'RU',
#    'sunrise': 1562982677,
#    'sunset': 1563037367},
#   'timezone': 10800,
#   'id': 823676,
#   'name': 'Gornoye Loo',
#   'cod': 200},
#  {'coord': {'lon': 15.06, 'lat': -13.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 50.66,
#    'pressure': 1019.13,
#    'humidity': 39,
#    'temp_min': 50.66,
#    'temp_max': 50.66,
#    'sea_level': 1019.13,
#    'grnd_level': 855.56},
#   'wind': {'speed': 2.44, 'deg': 7.229},
#   'clouds': {'all': 0},
#   'dt': 1562982556,
#   'sys': {'message': 0.006,
#    'country': 'AO',
#    'sunrise': 1562995444,
#    'sunset': 1563036385},
#   'timezone': 3600,
#   'id': 3351380,
#   'name': 'Caconda',
#   'cod': 200},
#  {'coord': {'lon': 12.15, 'lat': -15.19},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 64.7,
#    'pressure': 1014.82,
#    'humidity': 85,
#    'temp_min': 64.7,
#    'temp_max': 64.7,
#    'sea_level': 1014.82,
#    'grnd_level': 1014.7},
#   'wind': {'speed': 1.16, 'deg': 185.82},
#   'clouds': {'all': 1},
#   'dt': 1562982557,
#   'sys': {'message': 0.007,
#    'country': 'AO',
#    'sunrise': 1562996291,
#    'sunset': 1563036935},
#   'timezone': 3600,
#   'id': 3347019,
#   'name': 'Namibe',
#   'cod': 200},
#  {'coord': {'lon': 46.72, 'lat': 24.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 84.2,
#    'pressure': 1006,
#    'humidity': 12,
#    'temp_min': 84.2,
#    'temp_max': 84.2},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 300},
#   'clouds': {'all': 0},
#   'dt': 1562982306,
#   'sys': {'type': 1,
#    'id': 7424,
#    'message': 0.0064,
#    'country': 'SA',
#    'sunrise': 1562983928,
#    'sunset': 1563032703},
#   'timezone': 10800,
#   'id': 108410,
#   'name': 'Riyadh',
#   'cod': 200},
#  {'coord': {'lon': -85.87, 'lat': 11.25},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 79.46,
#    'pressure': 1010.74,
#    'humidity': 75,
#    'temp_min': 79.46,
#    'temp_max': 79.46,
#    'sea_level': 1010.74,
#    'grnd_level': 999.96},
#   'wind': {'speed': 14.92, 'deg': 84.663},
#   'clouds': {'all': 100},
#   'dt': 1562982557,
#   'sys': {'message': 0.0064,
#    'country': 'NI',
#    'sunrise': 1562930808,
#    'sunset': 1562976657},
#   'timezone': -21600,
#   'id': 3616726,
#   'name': 'San Juan del Sur',
#   'cod': 200},
#  {'coord': {'lon': 142.16, 'lat': -34.18},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 51.1,
#    'pressure': 1024,
#    'humidity': 76,
#    'temp_min': 50,
#    'temp_max': 52},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 270},
#   'clouds': {'all': 0},
#   'dt': 1562982557,
#   'sys': {'type': 1,
#    'id': 9550,
#    'message': 0.0122,
#    'country': 'AU',
#    'sunrise': 1562967346,
#    'sunset': 1563003470},
#   'timezone': 36000,
#   'id': 2157698,
#   'name': 'Mildura',
#   'cod': 200},
#  {'coord': {'lon': 75.32, 'lat': 51.72},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 72.62,
#    'pressure': 1013.89,
#    'humidity': 59,
#    'temp_min': 72.62,
#    'temp_max': 72.62,
#    'sea_level': 1013.89,
#    'grnd_level': 993.93},
#   'wind': {'speed': 12.26, 'deg': 48.606},
#   'clouds': {'all': 49},
#   'dt': 1562982558,
#   'sys': {'message': 0.0079,
#    'country': 'KZ',
#    'sunrise': 1562972096,
#    'sunset': 1563030806},
#   'timezone': 21600,
#   'id': 1524325,
#   'name': 'Ekibastuz',
#   'cod': 200},
#  {'coord': {'lon': -64.62, 'lat': 18.42},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 81.09,
#    'pressure': 1016,
#    'humidity': 74,
#    'temp_min': 79,
#    'temp_max': 82.4},
#   'visibility': 16093,
#   'wind': {'speed': 10.29, 'deg': 120},
#   'clouds': {'all': 40},
#   'dt': 1562982479,
#   'sys': {'type': 1,
#    'id': 8799,
#    'message': 0.0068,
#    'country': 'VG',
#    'sunrise': 1562924949,
#    'sunset': 1562972315},
#   'timezone': -14400,
#   'id': 3577430,
#   'name': 'Road Town',
#   'cod': 200},
#  {'coord': {'lon': 90.74, 'lat': 22.34},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 81.08,
#    'pressure': 1004.86,
#    'humidity': 85,
#    'temp_min': 81.08,
#    'temp_max': 81.08,
#    'sea_level': 1004.86,
#    'grnd_level': 1004.86},
#   'wind': {'speed': 9.1, 'deg': 256.793},
#   'rain': {'3h': 6.188},
#   'clouds': {'all': 100},
#   'dt': 1562982558,
#   'sys': {'message': 0.009,
#    'country': 'BD',
#    'sunrise': 1562973631,
#    'sunset': 1563021868},
#   'timezone': 21600,
#   'id': 1185251,
#   'name': 'Lalmohan',
#   'cod': 200},
#  {'coord': {'lon': 33.71, 'lat': -4},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.72,
#    'pressure': 1016.29,
#    'humidity': 60,
#    'temp_min': 62.72,
#    'temp_max': 62.72,
#    'sea_level': 1016.29,
#    'grnd_level': 890.17},
#   'wind': {'speed': 6.8, 'deg': 142.384},
#   'clouds': {'all': 89},
#   'dt': 1562982558,
#   'sys': {'message': 0.0075,
#    'country': 'TZ',
#    'sunrise': 1562990009,
#    'sunset': 1563032867},
#   'timezone': 10800,
#   'id': 159382,
#   'name': 'Igurubi',
#   'cod': 200},
#  {'coord': {'lon': -173.98, 'lat': -18.65},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1013,
#    'humidity': 73,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 150},
#   'clouds': {'all': 75},
#   'dt': 1562982558,
#   'sys': {'type': 1,
#    'id': 7292,
#    'message': 0.0066,
#    'country': 'TO',
#    'sunrise': 1563041321,
#    'sunset': 1563081254},
#   'timezone': 46800,
#   'id': 4032420,
#   'name': 'Neiafu',
#   'cod': 200},
#  {'coord': {'lon': 97.53, 'lat': 50.6},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 66.14,
#    'pressure': 1009.34,
#    'humidity': 56,
#    'temp_min': 66.14,
#    'temp_max': 66.14,
#    'sea_level': 1009.34,
#    'grnd_level': 825.98},
#   'wind': {'speed': 5.23, 'deg': 138.34},
#   'clouds': {'all': 100},
#   'dt': 1562982559,
#   'sys': {'message': 0.0065,
#    'country': 'RU',
#    'sunrise': 1562967094,
#    'sunset': 1563025146},
#   'timezone': 25200,
#   'id': 1501377,
#   'name': 'Kungurtug',
#   'cod': 200},
#  {'coord': {'lon': -1, 'lat': 37.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 79.59,
#    'pressure': 1014,
#    'humidity': 41,
#    'temp_min': 77,
#    'temp_max': 81},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 230},
#   'clouds': {'all': 0},
#   'dt': 1562982559,
#   'sys': {'type': 1,
#    'id': 6413,
#    'message': 0.0079,
#    'country': 'ES',
#    'sunrise': 1562993557,
#    'sunset': 1563045981},
#   'timezone': 7200,
#   'id': 2520058,
#   'name': 'Cartagena',
#   'cod': 200},
#  {'coord': {'lon': 73.37, 'lat': 5.44},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 83.42,
#    'pressure': 1011.88,
#    'humidity': 74,
#    'temp_min': 83.42,
#    'temp_max': 83.42,
#    'sea_level': 1011.88,
#    'grnd_level': 1012.07},
#   'wind': {'speed': 6.8, 'deg': 163.048},
#   'clouds': {'all': 56},
#   'dt': 1562982332,
#   'sys': {'message': 0.0092,
#    'country': 'MV',
#    'sunrise': 1562979576,
#    'sunset': 1563024261},
#   'timezone': 18000,
#   'id': 1337616,
#   'name': 'Naifaru',
#   'cod': 200},
#  {'coord': {'lon': -89.95, 'lat': 38.81},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 81.86,
#    'pressure': 1015,
#    'humidity': 69,
#    'temp_min': 75.99,
#    'temp_max': 84.2},
#   'visibility': 16093,
#   'wind': {'speed': 4.7},
#   'clouds': {'all': 5},
#   'dt': 1562982300,
#   'sys': {'type': 1,
#    'id': 3278,
#    'message': 0.0125,
#    'country': 'US',
#    'sunrise': 1562928274,
#    'sunset': 1562981149},
#   'timezone': -18000,
#   'id': 4237717,
#   'name': 'Edwardsville',
#   'cod': 200},
#  {'coord': {'lon': -118.79, 'lat': 55.17},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'pressure': 1011,
#    'humidity': 43,
#    'temp_min': 73.4,
#    'temp_max': 73.4},
#   'visibility': 40233,
#   'wind': {'speed': 13.87, 'deg': 270, 'gust': 9.8},
#   'clouds': {'all': 20},
#   'dt': 1562982560,
#   'sys': {'type': 1,
#    'id': 900,
#    'message': 0.0068,
#    'country': 'CA',
#    'sunrise': 1562931065,
#    'sunset': 1562992202},
#   'timezone': -21600,
#   'id': 5964347,
#   'name': 'Grande Prairie',
#   'cod': 200},
#  {'coord': {'lon': -52.1, 'lat': -32.03},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 59.3,
#    'pressure': 1012.91,
#    'humidity': 96,
#    'temp_min': 59.3,
#    'temp_max': 59.3,
#    'sea_level': 1012.91,
#    'grnd_level': 1011.91},
#   'wind': {'speed': 5.32, 'deg': 301.916},
#   'rain': {'3h': 0.125},
#   'clouds': {'all': 27},
#   'dt': 1562982397,
#   'sys': {'message': 0.0081,
#    'country': 'BR',
#    'sunrise': 1562927277,
#    'sunset': 1562963977},
#   'timezone': -10800,
#   'id': 3451138,
#   'name': 'Rio Grande',
#   'cod': 200},
#  {'coord': {'lon': -135.01, 'lat': 68.22},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 55.4,
#    'pressure': 1011,
#    'humidity': 54,
#    'temp_min': 55.4,
#    'temp_max': 55.4},
#   'visibility': 24140,
#   'wind': {'speed': 8.05, 'deg': 240},
#   'clouds': {'all': 20},
#   'dt': 1562982560,
#   'sys': {'type': 1,
#    'id': 796,
#    'message': 0.0119,
#    'country': 'CA',
#    'sunrise': 0,
#    'sunset': 0},
#   'timezone': -21600,
#   'id': 5882953,
#   'name': 'Aklavik',
#   'cod': 200},
#  {'coord': {'lon': 112.56, 'lat': 37.86},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1007,
#    'humidity': 47,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 10000,
#   'wind': {'speed': 2.24},
#   'clouds': {'all': 0},
#   'dt': 1562982560,
#   'sys': {'type': 1,
#    'id': 9616,
#    'message': 0.0056,
#    'country': 'CN',
#    'sunrise': 1562966252,
#    'sunset': 1563018773},
#   'timezone': 28800,
#   'id': 1793511,
#   'name': 'Taiyuan',
#   'cod': 200},
#  {'coord': {'lon': 122.88, 'lat': -0.91},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 63.62,
#    'pressure': 1013.21,
#    'humidity': 95,
#    'temp_min': 63.62,
#    'temp_max': 63.62,
#    'sea_level': 1013.21,
#    'grnd_level': 882.79},
#   'wind': {'speed': 6.55, 'deg': 171.431},
#   'rain': {'3h': 0.938},
#   'clouds': {'all': 100},
#   'dt': 1562982561,
#   'sys': {'message': 0.0078,
#    'country': 'ID',
#    'sunrise': 1562968309,
#    'sunset': 1563011762},
#   'timezone': 28800,
#   'id': 1637001,
#   'name': 'Biak',
#   'cod': 200},
#  {'coord': {'lon': 116.85, 'lat': -20.74},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 81.08,
#    'pressure': 1022.74,
#    'humidity': 13,
#    'temp_min': 81.08,
#    'temp_max': 81.08,
#    'sea_level': 1022.74,
#    'grnd_level': 1011.99},
#   'wind': {'speed': 23.47, 'deg': 91.202},
#   'clouds': {'all': 0},
#   'dt': 1562982383,
#   'sys': {'message': 0.0066,
#    'country': 'AU',
#    'sunrise': 1562971754,
#    'sunset': 1563011212},
#   'timezone': 28800,
#   'id': 6620339,
#   'name': 'Karratha',
#   'cod': 200},
#  {'coord': {'lon': 37.18, 'lat': 35.3},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 68.12,
#    'pressure': 1006.18,
#    'humidity': 83,
#    'temp_min': 68.12,
#    'temp_max': 68.12,
#    'sea_level': 1006.18,
#    'grnd_level': 961.9},
#   'wind': {'speed': 13, 'deg': 247.202},
#   'clouds': {'all': 0},
#   'dt': 1562982561,
#   'sys': {'message': 0.0056,
#    'country': 'SY',
#    'sunrise': 1562984765,
#    'sunset': 1563036446},
#   'timezone': 10800,
#   'id': 172515,
#   'name': 'Abu Samrah',
#   'cod': 200}]

# %%
# Set up variables to capture data
latitude = []
name = []
temp = []
clouds = []
humidity = []
wind = []
country = []

# Loop through JSON to capture data
for i in range(0,len(weather_json)):
    latitude.append(weather_json[i]['coord']['lat'])
    name.append(weather_json[i]['name'])
    temp.append(weather_json[i]['main']['temp'])
    clouds.append(weather_json[i]['clouds']['all'])
    humidity.append(weather_json[i]['main']['humidity'])
    wind.append(weather_json[i]['wind']['speed'])
    country.append(weather_json[i]['sys']['country'])

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary with all the info collected
weather_dict = {'City': name,
                'Country' : country,
               'Latitude' : latitude,
               'Temperature': temp,
               'Cloudiness %' : clouds,
               'Humidity %': humidity,
               'Wind Speed': wind}

# Create DataFrame and export it to csv file
weather_df = pd.DataFrame(data = weather_dict)
weather_df.to_csv('Weather Data.csv')
weather_df.head()
# Out:
#            City Country  Latitude  Temperature  Cloudiness %  Humidity %  \
# 0  Punta Arenas      CL    -53.16        41.00            90          93
# 1       Mataura      NZ    -46.19        54.00            98          73
# 2          Hilo      US     19.71        80.06            40          58
# 3     Cape Town      ZA    -33.93        49.77             0         100
# 4     Jamestown      AU    -33.21        51.20            15          64
#
#    Wind Speed
# 0       12.75
# 1        1.01
# 2       10.29
# 3        1.12
# 4       14.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
Temperature_Plot = plt.scatter(weather_df['Latitude'], weather_df['Temperature'])

plt.grid()
plt.title('Latitude vs. Temperature (F) 7/12/19')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.savefig('Temperature_Plot.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
Humidity_Plot = plt.scatter(weather_df['Latitude'], weather_df['Humidity %'])

plt.grid()
plt.title('Latitude vs. Humidity 7/12/19')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.savefig('Humidity %')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
Cloudiness_Plot = plt.scatter(weather_df['Latitude'], weather_df['Cloudiness %'])

plt.grid()
plt.title('Latitude vs. Cloudiness 7/12/19')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.savefig('Cloudiness %')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
Cloudiness_Plot = plt.scatter(weather_df['Latitude'], weather_df['Wind Speed'])

plt.grid()
plt.title('Latitude vs. Wind Speed 7/12/19')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig('Wind Speed')
